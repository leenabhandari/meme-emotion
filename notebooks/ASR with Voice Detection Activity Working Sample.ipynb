# %%
import http.client

conn = http.client.HTTPSConnection("apis.sentient.io")

payload = "{\"model\":\"news_parliament\",\"wav_base64\":\"...\",\"file_type\":\"wav\",\"threshold\":0.4}"

headers = {
    'content-type': "application/json",
    'x-api-key': "AA3E8AB23B374C6BB7C4"
    }

conn.request("POST", "/microservices/voice/vadasr/v1/getpredictions", payload, headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"message":"Successfully Processed","results":{"output":[{"end":10.48,"seqNum":1,"start":5.44,"text":"THE MINOR A NEARBY"},{"end":15.72,"seqNum":2,"start":12.72,"text":"THESE REASONS WHEN YOU DO"},{"end":21.32,"seqNum":3,"start":18.48,"text":"MY ANSWER IS NO"},{"end":49.0,"seqNum":4,"start":47.0,"text":"THE WORLD"},{"end":57.44,"seqNum":5,"start":55.24,"text":"THE RECOVERY"}]},"status":"Success"}
